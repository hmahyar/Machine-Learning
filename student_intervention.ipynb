# %% [markdown]
# # Project 2: Supervised Learning
# ### Building a Student Intervention System

# %% [markdown]
# ## 1. Classification vs Regression
#
# Your goal is to identify students who might need early intervention - which type of supervised machine learning problem is this, classification or regression? Why?

# %% [markdown]
# ## 2. Exploring the Data
#
# Let's go ahead and read in the student dataset first.
#
# _To execute a code cell, click inside it and press **Shift+Enter**._

# %%
# Import libraries
import numpy as np
import pandas as pd

# %%
# Read student data
student_data = pd.read_csv("student-data.csv")
print "Student data read successfully!"
# Note: The last column 'passed' is the target/label, all other are feature columns
# Out:
# Student data read successfully!

# %% [markdown]
# Now, can you find out the following facts about the dataset?
# - Total number of students
# - Number of students who passed
# - Number of students who failed
# - Graduation rate of the class (%)
# - Number of features
#
# _Use the code block below to compute these values. Instructions/steps are marked using **TODO**s._

# %%
# TODO: Compute desired values - replace each '?' with an appropriate expression/function call
n_students = student_data['school'].size
n_features = len(student_data.columns[:-1])
n_passed = len(student_data['passed'][(student_data.passed=='yes')])
n_failed = len(student_data['passed'][(student_data.passed=='no')])
grad_rate = (n_passed*100.0)/n_students
print "Total number of students: {}".format(n_students)
print "Number of students who passed: {}".format(n_passed)
print "Number of students who failed: {}".format(n_failed)
print "Number of features: {}".format(n_features)
print "Graduation rate of the class: {:.2f}%".format(grad_rate)
# Out:
# Total number of students: 395
# Number of students who passed: 265
# Number of students who failed: 130
# Number of features: 30
# Graduation rate of the class: 67.09%

# %% [markdown]
# ## 3. Preparing the Data
# In this section, we will prepare the data for modeling, training and testing.
#
# ### Identify feature and target columns
# It is often the case that the data you obtain contains non-numeric features. This can be a problem, as most machine learning algorithms expect numeric data to perform computations with.
#
# Let's first separate our data into feature and target columns, and see if any features are non-numeric.<br/>
# **Note**: For this dataset, the last column (`'passed'`) is the target or label we are trying to predict.

# %%
# Extract feature (X) and target (y) columns
feature_cols = list(student_data.columns[:-1])  # all columns but last are features
target_col = student_data.columns[-1]  # last column is the target/label
print "Feature column(s):-\n{}".format(feature_cols)
print "Target column: {}".format(target_col)

X_all = student_data[feature_cols]  # feature values for all students
y_all = student_data[target_col]  # corresponding targets/labels
print "\nFeature values:-"
print X_all.head()  # print the first 5 rows
# Out:
# Feature column(s):-
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']
# Target column: passed
#
# Feature values:-
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#     ...    higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0   ...       yes       no        no       4         3     4    1    1      3
# 1   ...       yes      yes        no       5         3     3    1    1      3
# 2   ...       yes      yes        no       4         3     2    2    3      3
# 3   ...       yes      yes       yes       3         2     2    1    1      5
# 4   ...       yes       no        no       4         3     2    1    2      5
#
#   absences
# 0        6
# 1        4
# 2       10
# 3        2
# 4        4
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Preprocess feature columns
#
# As you can see, there are several non-numeric columns that need to be converted! Many of them are simply `yes`/`no`, e.g. `internet`. These can be reasonably converted into `1`/`0` (binary) values.
#
# Other columns, like `Mjob` and `Fjob`, have more than two values, and are known as _categorical variables_. The recommended way to handle such a column is to create as many columns as possible values (e.g. `Fjob_teacher`, `Fjob_other`, `Fjob_services`, etc.), and assign a `1` to one of them and `0` to all others.
#
# These generated columns are sometimes called _dummy variables_, and we will use the [`pandas.get_dummies()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html?highlight=get_dummies#pandas.get_dummies) function to perform this transformation.

# %%
# Preprocess feature columns
def preprocess_features(X):
    outX = pd.DataFrame(index=X.index)  # output dataframe, initially empty

    # Check each column
    for col, col_data in X.iteritems():
        # If data type is non-numeric, try to replace all yes/no values with 1/0
        if col_data.dtype == object:
            col_data = col_data.replace(['yes', 'no'], [1, 0])
        # Note: This should change the data type for yes/no columns to int

        # If still non-numeric, convert to one or more dummy variables
        if col_data.dtype == object:
            col_data = pd.get_dummies(col_data, prefix=col)  # e.g. 'school' => 'school_GP', 'school_MS'

        outX = outX.join(col_data)  # collect column(s) in output dataframe

    return outX

X_all = preprocess_features(X_all)
print "Processed feature columns ({}):-\n{}".format(len(X_all.columns), list(X_all.columns))
# Out:
# Processed feature columns (48):-
# ['school_GP', 'school_MS', 'sex_F', 'sex_M', 'age', 'address_R', 'address_U', 'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Medu', 'Fedu', 'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home', 'reason_other', 'reason_reputation', 'guardian_father', 'guardian_mother', 'guardian_other', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']

# %% [markdown]
# ### Split data into training and test sets
#
# So far, we have converted all _categorical_ features into numeric values. In this next step, we split the data (both features and corresponding labels) into training and test sets.

# %%
# First, decide how many training vs test samples you want
num_all = student_data.shape[0]  # same as len(student_data)
num_train = 300  # about 75% of the data
num_test = num_all - num_train
 
# TODO: Then, select features (X) and corresponding labels (y) for the training and test sets
# Note: Shuffle the data or randomly select samples to avoid any bias due to ordering in the dataset
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_all,y_all, test_size = num_test ,random_state=5)
print "Training set: {} samples".format(X_train.shape[0])
print "Test set: {} samples".format(X_test.shape[0])
# Note: If you need a validation set, extract it from within training data
# Out:
# Training set: 300 samples
# Test set: 95 samples

# %% [markdown]
# ## 4. Training and Evaluating Models
# Choose 3 supervised learning models that are available in scikit-learn, and appropriate for this problem. For each model:
#
# - What are the general applications of this model? What are its strengths and weaknesses?
# - Given what you know about the data so far, why did you choose this model to apply?
# - Fit this model to the training data, try to predict labels (for both training and test sets), and measure the F<sub>1</sub> score. Repeat this process with different training set sizes (100, 200, 300), keeping test set constant.
#
# Produce a table showing training time, prediction time, F<sub>1</sub> score on training set and F<sub>1</sub> score on test set, for each training set size.
#
# Note: You need to produce 3 such tables - one for each model.

# %%
# Train a model
import time

def train_classifier(clf, X_train, y_train):
    print "Training {}...".format(clf.__class__.__name__)
    start = time.time()
    clf.fit(X_train, y_train)
    end = time.time()
    print "Done!\nTraining time (secs): {:.3f}".format(end - start)

# TODO: Choose a model, import it and instantiate an object
from sklearn import svm
clf = svm.SVC()

# Fit model to training data
train_classifier(clf, X_train, y_train)  # note: using entire training set here
#print clf  # you can inspect the learned model by printing it
# Out:
# Training SVC...
# Done!
# Training time (secs): 0.007

# %%
# Predict on training set and compute F1 score
from sklearn.metrics import f1_score

def predict_labels(clf, features, target):
    print "Predicting labels using {}...".format(clf.__class__.__name__)
    start = time.time()
    y_pred = clf.predict(features)
    end = time.time()
    print "Done!\nPrediction time (secs): {:.3f}".format(end - start)
    return f1_score(target.values, y_pred, pos_label='yes')

train_f1_score = predict_labels(clf, X_train, y_train)
print "F1 score for training set: {}".format(train_f1_score)
# Out:
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.005
# F1 score for training set: 0.876355748373

# %%
# Predict on test data
print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))
# Out:
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.002
# F1 score for test set: 0.765957446809

# %%
# Train and predict using different training set sizes
def train_predict(clf, X_train, y_train, X_test, y_test):
    print "------------------------------------------"
    print "Training set size: {}".format(len(X_train))
    train_classifier(clf, X_train, y_train)
    print "F1 score for training set: {}".format(predict_labels(clf, X_train, y_train))
    print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))

# TODO: Run the helper function above for desired subsets of training data
import numpy as np
#sizes = np.round(np.linspace(2,len(X_train),3))
for s in [100,200,300]:
    clf = svm.SVC()
    train_predict(clf,X_train[0:s],y_train[0:s],X_test,y_test)

# Note: Keep the test set constant
# Out:
# ------------------------------------------
# Training set size: 100
# Training SVC...
# Done!
# Training time (secs): 0.001
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.001
# F1 score for training set: 0.851851851852
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.001
# F1 score for test set: 0.789808917197
# ------------------------------------------
# Training set size: 200
# Training SVC...
# Done!
# Training time (secs): 0.003
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.002
# F1 score for training set: 0.861635220126
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.001
# F1 score for test set: 0.786666666667
# ------------------------------------------
# Training set size: 300
# Training SVC...
# Done!
# Training time (secs): 0.007
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.005
# F1 score for training set: 0.876355748373
# Predicting labels using SVC...
# Done!
# Prediction time (secs): 0.002
# F1 score for test set: 0.765957446809

# %%
# TODO: Train and predict using two other models

from sklearn import tree
clf = tree.DecisionTreeClassifier()
train_classifier(clf,X_train,y_train)
print "F1 score for training set: {}".format(predict_labels(clf, X_train, y_train))
print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))
print '\n\nTraining set size Test'
for s in [100,200,300]:
    train_predict(clf,X_train[0:s],y_train[0:s],X_test,y_test)
    print '\n\n'


from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=11)
train_classifier(clf,X_train,y_train)
print "F1 score for training set: {}".format(predict_labels(clf, X_train, y_train))
print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))
print '\n\nTraining set size Test'
for s in [100,200,300]:
    train_predict(clf,X_train[0:s],y_train[0:s],X_test,y_test)
# Out:
# Training DecisionTreeClassifier...
# Done!
# Training time (secs): 0.002
# Predicting labels using DecisionTreeClassifier...
# Done!
# Prediction time (secs): 0.000
# F1 score for training set: 1.0
# Predicting labels using DecisionTreeClassifier...
# Done!
# Prediction time (secs): 0.000
# F1 score for test set: 0.704
#
#
# Training set size Test
#
#
#
# Training AdaBoostClassifier...
# Done!
# Training time (secs): 0.019
# Predicting labels using AdaBoostClassifier...
# Done!
# Prediction time (secs): 0.002
# F1 score for training set: 0.828828828829
# Predicting labels using AdaBoostClassifier...
# Done!
# Prediction time (secs): 0.001
# F1 score for test set: 0.832116788321
#
#
# Training set size Test

# %% [markdown]
# # 5. Choosing the Best Model
#
# - Based on the experiments you performed earlier, in 1-2 paragraphs explain to the board of supervisors what single model you chose as the best model. Which model is generally the most appropriate based on the available data, limited resources, cost, and performance?
# - In 1-2 paragraphs explain to the board of supervisors in layman's terms how the final model chosen is supposed to work (for example if you chose a Decision Tree or Support Vector Machine, how does it make a prediction).
# - Fine-tune the model. Use Gridsearch with at least one important parameter tuned and with at least 3 settings. Use the entire training set for this.
# - What is the model's final F<sub>1</sub> score?

# %%
# TODO: Fine-tune your model and report the best F1 score


clf = svm.SVC(kernel='poly' ,coef0= 0.0, gamma= 'auto', degree= 2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_train)
print "F1 score for training set: {}".format(f1_score(y_train, y_pred, pos_label='yes'))
y_pred = clf.predict(X_test)
print "F1 score for test set: {}".format(f1_score(y_test, y_pred, pos_label='yes'))
# Out:
# F1 score for training set: 0.867256637168
# F1 score for test set: 0.788732394366

# %%
#Note: Model Tuning
from sklearn import grid_search, datasets
clf = svm.SVC()
parameters = {'kernel': ('poly', 'rbf', 'sigmoid'),'degree':(2,3,4),'gamma':('auto',0.2),'coef0':(0.0,0.2)}
grid = grid_search.GridSearchCV(clf, parameters,cv=10, verbose=3)
print grid.fit(X_all,y_all)
print '\n\n\n\n','The Best:',grid.best_params_
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.725000 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.725000 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.775000 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.625000 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.769231 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.589744 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.589744 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.717949 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=2, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.550000 -   0.4s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.750000 -   0.7s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.2s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.725000 -   0.8s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.525000 -   0.3s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.8s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.564103 -   0.4s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.589744 -   0.3s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.487179 -   0.7s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=2, score=0.589744 -   1.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=3, score=0.538462 -   0.1s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=3, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.538462 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=3, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.600000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.538462 -   0.1s
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 127 tasks       | elapsed:    9.4s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.0, gamma=auto, degree=4, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.0, gamma=auto, degree=4, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.600000 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.538462 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.0, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.0, gamma=0.2, degree=4, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.0, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.0, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.700000 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.725000 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.725000 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.775000 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.600000 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.769231 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.589744 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.589744 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.717949 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=2 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=2 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=2, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=2 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=2, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.550000 -   0.7s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.750000 -   0.7s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.2s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.725000 -   0.8s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.525000 -   0.4s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.641026 -   0.7s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.564103 -   0.4s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.589744 -   0.3s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.487179 -   0.7s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=2 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=2, score=0.589744 -   1.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=2 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=2, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.692308 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.589744 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=3 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=3, score=0.538462 -   0.1s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=3 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=3, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=3 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=3, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.538462 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.615385 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=3 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=3, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=3 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=3, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.575000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.538462 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=auto, degree=4 ....................
# [CV]  kernel=poly, coef0=0.2, gamma=auto, degree=4, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.750000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.700000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.692308 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.641026 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=auto, degree=4 .....................
# [CV]  kernel=rbf, coef0=0.2, gamma=auto, degree=4, score=0.692308 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=auto, degree=4 .................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=auto, degree=4, score=0.666667 -   0.0s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.625000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.650000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.700000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.600000 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.538462 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.641026 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.564103 -   0.1s
# [CV] kernel=poly, coef0=0.2, gamma=0.2, degree=4 .....................
# [CV]  kernel=poly, coef0=0.2, gamma=0.2, degree=4, score=0.512821 -   0.1s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.650000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=rbf, coef0=0.2, gamma=0.2, degree=4 ......................
# [CV]  kernel=rbf, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.675000 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks       | elapsed:   19.9s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:   22.2s finished
# [CV] kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4 ..................
# [CV]  kernel=sigmoid, coef0=0.2, gamma=0.2, degree=4, score=0.666667 -   0.0s
# GridSearchCV(cv=10, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'kernel': ('poly', 'rbf', 'sigmoid'), 'coef0': (0.0, 0.2), 'gamma': ('auto', 0.2), 'degree': (2, 3, 4)},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=3)
#
#
#
#
# The Best: {'kernel': 'poly', 'coef0': 0.0, 'gamma': 'auto', 'degree': 2}
